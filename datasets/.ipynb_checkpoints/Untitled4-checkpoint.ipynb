# %%
import os
import tarfile
import urllib.request

RES_PATH = os.path.join("res_datasets","resourceing")

def fetch_resource_data(res_path=RES_PATH):
    if not os.path.isdir(res_path):
        os.makedirs(res_path)
##创建文件夹路径函数
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

def plot_learning_curves(model, X, y):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.4, random_state=30)
    train_errors, val_errors = [], []
    for m in range(1, len(X_train) + 1):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict = model.predict(X_train[:m])
        y_val_predict = model.predict(X_val)
        train_errors.append(mean_squared_error(y_train[:m], y_train_predict))
        val_errors.append(mean_squared_error(y_val, y_val_predict))

    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train")
    plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="val")
    plt.legend(loc="upper right", fontsize=14)   # not shown in the book
    plt.xlabel("Training set size", fontsize=14) # not shown
    plt.ylabel("RMSE", fontsize=14)              # not shown
    
fetch_resource_data() ##调用创建

##读取CSV文件
import pandas as pd

def load_res_data(res_path = RES_PATH,file_name="resource_total.csv"):
    csv_path = os.path.join(RES_PATH,file_name)
    return pd.read_csv(csv_path)

# %%
##数据处理
resource_origin_data = load_res_data()  #get origin csv data

#%matplotlib inline
#import matplotlib.pyplot as plt
#resource_origin_data.hist(bins=50, figsize=(20,15))
#plt.show() #data plot show

resource_origin_data_lut = resource_origin_data.dropna(subset = ["LUT"])
resource_origin_data_lut=resource_origin_data_lut.drop("FF",axis=1)
resource_origin_data_lut=resource_origin_data_lut.drop("BUFG",axis=1)
resource_origin_data_lut=resource_origin_data_lut.drop("IO",axis=1)
resource_origin_data_lut=resource_origin_data_lut.drop("ModuleName",axis=1)
resource_origin_data_lut=resource_origin_data_lut.drop("PARAMETERVALUE",axis=1)
resource_origin_data_lut=resource_origin_data_lut.drop("ModuleInsts",axis=1)

# %%
#数据信息
resource_origin_data_lut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 203
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AlwaysConstructs         190 non-null    int64
#  1   AssignLHSPortNum         190 non-null    int64
#  2   AssignLHSWidth           190 non-null    int64
#  3   AssignRHSPortNum         190 non-null    int64
#  4   AssignRHSWidth           190 non-null    int64
#  5   AssignStmts              190 non-null    int64
#  6   BLOCKINGASSIGN           190 non-null    int64
#  7   CASECONDITIONNUM         190 non-null    int64
#  8   CASECONDITIONWIDTH       190 non-null    int64
#  9   CASEITEMCONDITIONNUM     190 non-null    int64
#  10  CASEITEMCONDITIOWIDTH    190 non-null    int64
#  11  CASEITEMNUM              190 non-null    int64
#  12  CONDITIONALELSE          190 non-null    int64
#  13  CONDITIONALIF            190 non-null    int64
#  14  CONDITIONALTHEN          190 non-null    int64
#  15  FORBLOCK                 190 non-null    int64
#  16  FORTIMES                 190 non-null    int64
#  17  INDEXMEMRORY             190 non-null    int64
#  18  INOUT                    190 non-null    int64
#  19  INOUTWIDTH               190 non-null    int64
#  20  INPUT                    190 non-null    int64
#  21  INPUTWIDTH               190 non-null    int64
#  22  MIN                      190 non-null    int64
#  23  NonBlockingAssign        190 non-null    int64
#  24  NonBlockingLeftPortNum   190 non-null    int64
#  25  NonBlockingRightPortNum  190 non-null    int64
#  26  OUTPUT                   190 non-null    int64
#  27  OUTPUTWIDTH              190 non-null    int64
#  28  PARAMETERNUM             190 non-null    int64
#  29  QUESTIONCOLON            190 non-null    int64
#  30  QUESTIONCOLONELSE        190 non-null    int64
#  31  QUESTIONCOLONIF          190 non-null    int64
#  32  QUESTIONCOLONTHEN        190 non-null    int64
#  33  REDAND                   190 non-null    int64
#  34  REDAOR                   190 non-null    int64
#  35  REDXOR                   190 non-null    int64
#  36  REG                      190 non-null    int64
#  37  REGWIDTH                 190 non-null    int64
#  38  WIRENUM                  190 non-null    int64
#  39  WIREWIDTH                190 non-null    int64
#  40  LUT                      190 non-null    float64
# dtypes: float64(1), int64(40)
# memory usage: 62.3 KB

# %%
#相关性分析
corr_matrix=resource_origin_data_lut.corr()
corr_matrix["LUT"].sort_values(ascending=False)
# Out:
# LUT                        1.000000
# INPUTWIDTH                 0.405495
# INPUT                      0.322120
# REGWIDTH                   0.169618
# OUTPUTWIDTH                0.159731
# AssignLHSWidth             0.141814
# FORTIMES                   0.131176
# NonBlockingLeftPortNum     0.121413
# REG                        0.120196
# AssignRHSWidth             0.108965
# NonBlockingAssign          0.099178
# OUTPUT                     0.070296
# CONDITIONALIF              0.062467
# CONDITIONALTHEN            0.062467
# WIRENUM                    0.057424
# WIREWIDTH                  0.055784
# CONDITIONALELSE            0.044171
# AssignRHSPortNum           0.034980
# PARAMETERNUM               0.032905
# AlwaysConstructs           0.031033
# FORBLOCK                   0.024218
# NonBlockingRightPortNum    0.016093
# CASEITEMNUM                0.004153
# REDAND                     0.000511
# AssignStmts                0.000106
# REDAOR                    -0.001627
# AssignLHSPortNum          -0.002452
# INOUT                     -0.008291
# INDEXMEMRORY              -0.008545
# QUESTIONCOLONIF           -0.008895
# QUESTIONCOLONTHEN         -0.008895
# QUESTIONCOLONELSE         -0.008895
# QUESTIONCOLON             -0.008895
# MIN                       -0.009090
# INOUTWIDTH                -0.011609
# BLOCKINGASSIGN            -0.011850
# REDXOR                    -0.013398
# CASEITEMCONDITIONNUM      -0.018260
# CASEITEMCONDITIOWIDTH     -0.019265
# CASECONDITIONNUM          -0.031834
# CASECONDITIONWIDTH        -0.036681
# Name: LUT, dtype: float64

# %%
#特征优化
resource_lut = resource_origin_data_lut["LUT"].copy() #label data
resource_lut_data = resource_origin_data_lut.drop("LUT",axis=1) #feature data
resource_label = list(resource_lut_data) #labal list

# %%
#数据分割
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#训练集、测试集、验证集
X_train_full, X_test, y_train_full, y_test = train_test_split(resource_lut_data, resource_lut, test_size=0.4)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full)

# %%
X_train
# Out:
#      AlwaysConstructs  AssignLHSPortNum  AssignLHSWidth  AssignRHSPortNum  \
# 122                 1                 0               0                 0
# 123                 1                 0               0                 0
# 137                 1                 1               8                 1
# 34                  1                 1               1                 2
# 2                   0                 0               0                 0
# ..                ...               ...             ...               ...
# 111                 1                 0               0                 0
# 47                  1                 0               0                 0
# 181                 2                 4               4                 3
# 177                 3                 1               1                 1
# 90                  0                 1               1                 2
#
#      AssignRHSWidth  AssignStmts  BLOCKINGASSIGN  CASECONDITIONNUM  \
# 122               0            0               0                 0
# 123               0            0               2                 0
# 137               8            1               4                 0
# 34                0            1               0                 0
# 2                 0            1               0                 0
# ..              ...          ...             ...               ...
# 111               0            0               3                 0
# 47                0            0               0                 0
# 181               3            4              10                 2
# 177               1            1               0                 0
# 90                2            1               0                 0
#
#      CASECONDITIONWIDTH  CASEITEMCONDITIONNUM  ...  QUESTIONCOLONELSE  \
# 122                   0                     0  ...                  0
# 123                   0                     0  ...                  0
# 137                   0                     0  ...                  0
# 34                    0                     0  ...                  1
# 2                     0                     0  ...                  0
# ..                  ...                   ...  ...                ...
# 111                   0                     0  ...                  0
# 47                    0                     0  ...                  0
# 181                   3                     6  ...                  0
# 177                   0                     0  ...                  0
# 90                    0                     0  ...                  1
#
#      QUESTIONCOLONIF  QUESTIONCOLONTHEN  REDAND  REDAOR  REDXOR  REG  \
# 122                0                  0       0       0       0    1
# 123                0                  0       0       0       0    2
# 137                0                  0       0       0       0    1
# 34                 1                  1       0       0       0    1
# 2                  0                  0       0       0       0    0
# ..               ...                ...     ...     ...     ...  ...
# 111                0                  0       0       0       0    1
# 47                 0                  0       0       0       0    2
# 181                0                  0       3       0       1    3
# 177                0                  0       1       0       0    4
# 90                 1                  1       0       0       0    0
#
#      REGWIDTH  WIRENUM  WIREWIDTH
# 122         4        0          0
# 123         0        0          0
# 137         8        0          0
# 34          8        0          0
# 2           0        0          0
# ..        ...      ...        ...
# 111        16        0          0
# 47          0        0          0
# 181        13        3         11
# 177         0        6          6
# 90          0        0          0
#
# [114 rows x 40 columns]

# %%
#数据标准化
scaler = StandardScaler() 
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)
X_train_full = scaler.transform(X_train_full)
X_data_full = scaler.transform(resource_lut_data)

# %%
#随机森林
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(X_train,y_train)
forest_predic = forest_reg.predict(X_valid)
forest_mse = mean_squared_error(y_valid,forest_predic)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 311.37517364667815

# %%
from sklearn.metrics import r2_score
r2_score(y_valid,forest_predic)
# Out:
# -58.51038894693099

# %%
plot_learning_curves(forest_reg, X_train_full, y_train_full)
plt.axis([0, 300, 0, 1000])                         # not shown in the book
plt.show()

# %%
#随机森林贡献度分析
feature_importance = forest_reg.feature_importances_
sorted(zip(feature_importance, resource_label), reverse=True)
# Out:
# [(0.24678931044403693, 'INPUTWIDTH'),
#  (0.17967716028930794, 'INPUT'),
#  (0.13387315908427716, 'AssignLHSWidth'),
#  (0.10517524644575647, 'OUTPUTWIDTH'),
#  (0.07264321881088177, 'REGWIDTH'),
#  (0.054533116638225604, 'CASEITEMNUM'),
#  (0.04395325284828502, 'NonBlockingLeftPortNum'),
#  (0.04357417779028345, 'REG'),
#  (0.028806536680676502, 'AssignRHSWidth'),
#  (0.023211757255356524, 'NonBlockingAssign'),
#  (0.009362360616489995, 'CONDITIONALIF'),
#  (0.006495589575563375, 'MIN'),
#  (0.006461188002397967, 'WIREWIDTH'),
#  (0.005834153478564193, 'PARAMETERNUM'),
#  (0.005360860300955651, 'BLOCKINGASSIGN'),
#  (0.005155941008413689, 'OUTPUT'),
#  (0.003687152700227754, 'QUESTIONCOLONTHEN'),
#  (0.0033281595373614143, 'QUESTIONCOLON'),
#  (0.0029875406555345545, 'NonBlockingRightPortNum'),
#  (0.0024480401210407905, 'CONDITIONALTHEN'),
#  (0.002330251210383461, 'AssignRHSPortNum'),
#  (0.001984322869068943, 'WIRENUM'),
#  (0.0018741301937341991, 'CONDITIONALELSE'),
#  (0.0018414090506945926, 'CASECONDITIONWIDTH'),
#  (0.0015209404285905898, 'QUESTIONCOLONIF'),
#  (0.001346721913151477, 'CASECONDITIONNUM'),
#  (0.0012885191733134965, 'AlwaysConstructs'),
#  (0.001099684613706536, 'REDAND'),
#  (0.0010447636311840525, 'INDEXMEMRORY'),
#  (0.0008819500153223407, 'AssignLHSPortNum'),
#  (0.0005916055915481964, 'AssignStmts'),
#  (0.0005116775515676228, 'CASEITEMCONDITIONNUM'),
#  (0.00028712799291670684, 'QUESTIONCOLONELSE'),
#  (2.5232401853177018e-05, 'CASEITEMCONDITIOWIDTH'),
#  (1.0327737674267764e-05, 'REDXOR'),
#  (1.772441773788131e-06, 'REDAOR'),
#  (1.1095589226869264e-06, 'FORBLOCK'),
#  (5.313409571305774e-07, 'FORTIMES'),
#  (0.0, 'INOUTWIDTH'),
#  (0.0, 'INOUT')]

# %%
#随机搜索
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=1, high=100),
        'max_features': randint(low=1, high=15),
    }

forest_reg = RandomForestRegressor(random_state=42)
forest_rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=100, cv=5, scoring='neg_mean_squared_error', random_state=42)
forest_rnd_search.fit(X_train, y_train)

# %%
#随机森林mse
forest_predict = forest_rnd_search.best_estimator_.predict(X_valid)
forest_mse = mean_squared_error(y_valid,forest_predict)
forest_mse
# Out:
# 767861.9407894737

# %%
#随机森林rmse
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 876.2773195681112

# %%
#随机森林R方评估
from sklearn.metrics import r2_score
r2_score(y_valid,forest_predict)
# Out:
# -0.9218308995769509

# %%
plot_learning_curves(forest_rnd_search.best_estimator_, X_train_full, y_train_full)
plt.axis([0, 150, 0, 500])                         # not shown in the book
plt.show()
